# %%
import pandas as pd

df = pd.read_csv('../data/CT_GTFS/stop_times.txt') # reading stop times
print(df.columns.tolist())
print(df.head())
print(df.shape)
print(df['trip_id'].nunique())

routes = pd.read_csv('../data/CT_GTFS/routes.txt') # reading info on transit stops
print(routes.head())

trips = pd.read_csv('../data/CT_GTFS/trips.txt') # reading dataset of trips

merged = df.merge(trips[['trip_id','route_id']], on='trip_id')
merged = merged.merge(routes[['route_id','route_short_name']], on='route_id') # merge these columns in one dataframe

#print(merged[['route_short_name', 'arrival_time', 'stop_id', 'stop_sequence']].head(10))
print(merged['route_short_name'].value_counts()) # counts the number of stops
hour = (merged['arrival_time'].str[:2])
busy_hour = hour.value_counts()
print(busy_hour.head(5)) # prints the top 5 busiest hours
# Out:
# ['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence', 'pickup_type', 'drop_off_type', 'shape_dist_traveled', 'timepoint']
#     trip_id arrival_time departure_time  stop_id  stop_sequence  pickup_type  \
# 0  74468238     11:52:00       11:52:00     6451              1            0
# 1  74468238     11:53:00       11:53:00     6712              2            0
# 2  74468238     11:53:00       11:53:00     7276              3            0
# 3  74468238     11:59:00       11:59:00     8058              4            0
# 4  74468238     12:00:00       12:00:00     6338              5            0
#
#    drop_off_type  shape_dist_traveled  timepoint
# 0              0                0.000          1
# 1              0                0.557          0
# 2              0                0.866          0
# 3              0                5.359          1
# 4              0                5.659          0
# (887738, 9)
# 26755
#   route_id route_short_name                    route_long_name  route_desc  \
# 0  1-20789                1                Bowness/Forest Lawn         NaN
# 1  2-20789                2  Mount Pleasant/Killarney 17 Av SW         NaN
# 2  3-20789                3              Sandstone/Elbow Dr SW         NaN
# 3  4-20789                4                         Huntington         NaN
# 4  5-20789                5                        North Haven         NaN
#
#    route_type  route_url  route_color  route_text_color
# 0           3        NaN          NaN               NaN
# 1           3        NaN          NaN               NaN
# 2           3        NaN          NaN               NaN
# 3           3        NaN          NaN               NaN
# 4           3        NaN          NaN               NaN
# route_short_name
# 201    30573
# 43     29457
# 202    27116
# 23     25950
# 3      25691
#        ...
# 142      207
# 62       192
# 117      185
# 151      163
# 109      147
# Name: count, Length: 148, dtype: int64
# arrival_time
# 16    53581
# 17    52966
# 08    52147
# 15    51480
# 07    51431
# Name: count, dtype: int64
